# %%
#pip install bs4
#pip install requests
import re
import json
import csv
from io import StringIO
from bs4 import BeautifulSoup
import requests
from requests.auth import HTTPBasicAuth
from urllib.request import urlopen
from datetime import datetime

# %%
Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
Fields = ['Operating Income', 'Net Income From Continuing Operations', 'Retained Earnings', 'Change In Cash', 'Net Borrowings']

# %%
import requests
url = 'https://finance.yahoo.com/quote/JNJ/financials?p=JNJ'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])

# %%
json_data['context'].keys()
# Out:
# dict_keys(['dispatcher', 'options', 'plugins'])

# %%
json_data['context']['dispatcher'].keys()
# Out:
# dict_keys(['stores'])

# %%
json_data['context']['dispatcher']['stores'].keys()
# Out:
# dict_keys(['PageStore', 'MRTStore', 'RouteStore', 'I13nStore', 'PageTransitionStore', 'VideoPlayerStore', 'QuoteAutoCompleteStore', 'NavrailStore', 'StreamDataStore', 'QuoteSummaryStore', 'FinanceConfigStore', 'LangStore', 'BeaconStore', 'AdStore', 'VideoStore', 'ComponentConfigStore', 'CrumbStore', 'CompositeStore', 'MonalixaStore', 'StreamStore', 'UserStore', 'ProfileStore', 'QuotePageStore', 'FinancialTemplateStore', 'QuoteTimeSeriesStore', 'MarketTimeStore', 'FeatureBarStore', 'MarketSummaryStore', 'NavServiceStore', 'RecommendationStore', 'UHAccountSwitchStore', 'RmpStore', 'MobileHeaderStore'])

# %%
json_data['context']['dispatcher']['stores']['QuoteSummaryStore'].keys()
# Out:
# dict_keys(['financialsTemplate', 'cashflowStatementHistory', 'balanceSheetHistoryQuarterly', 'earnings', 'price', 'incomeStatementHistoryQuarterly', 'incomeStatementHistory', 'balanceSheetHistory', 'cashflowStatementHistoryQuarterly', 'quoteType', 'summaryDetail', 'symbol', 'pageViews'])

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/JNJ/financials?p=JNJ'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='JNJ'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='JNJ'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='JNJ'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
JNJ = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/BRK-B/financials?p=BRK-B'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='BRK-B'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='BRK-B'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='BRK-B'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
BRKB = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/JPM/financials?p=JPM'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='JPM'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='JPM'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='JPM'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
JPM = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/MMM/financials?p=MMM'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='MMM'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='MMM'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='MMM'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
MMM = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/ABBV/financials?p=ABBV'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='ABBV'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='ABBV'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='ABBV'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
ABBV = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/DIS/financials?p=DIS'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='DIS'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='DIS'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='DIS'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
DIS = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/T/financials?p=T'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='T'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='T'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='T'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
T = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/PG/financials?p=PG'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='PG'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='PG'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='PG'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
PG = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/LOW/financials?p=LOW'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='LOW'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='LOW'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='LOW'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
LOW = df_union_all

# %%
##------------------------------------------------------------------------------
##------------------------------------all------------------------
# Tickers = ['JNJ', 'BRK.B', 'JPM', 'MMM', 'ABBV', 'DIS', 'T', 'PG', 'LOW', 'CI']
import requests
from datetime import date
url = 'https://finance.yahoo.com/quote/CI/financials?p=CI'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
soup = BeautifulSoup(result.text, 'html.parser')
script_data = soup.find('script', text=pattern).contents[0]
start = script_data.find('context')-2
json_data = json.loads(script_data[start:-12])


quarterly_is = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']
quarterly_is_stmts=[]
for s in quarterly_is:
    statement = {}
    quarterly_is_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_is_stmts.append(statement)
df_quarterly_is_stmts= pd.DataFrame(quarterly_is_stmts)
df_quarterly_is_stmts
df_quarterly_is_stmts = df_quarterly_is_stmts.T
df_quarterly_is_stmts
df_quarterly_is_stmts['endDate'] = quarterly_is_data1
df_quarterly_is_stmts
df_quarterly_is_stmts['Ticker']='CI'
df_quarterly_is_stmts
index = [str(i) for i in (df_quarterly_is_stmts.index)]
df_quarterly_is_stmts =pd.DataFrame(data=df_quarterly_is_stmts ,index=index)
df_quarterly_is_stmts['Field'] = index
df_quarterly_is_stmts['Scrape Date'] = today
df_quarterly_is_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_is_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_is=df_quarterly_is_stmts
df_is=df_is[df_is.Field.isin(tic)]
df_is




quarterly_cf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['cashflowStatementHistoryQuarterly']['cashflowStatements']
quarterly_cf_stmts=[]
for s in quarterly_cf:
    statement = {}
    quarterly_cf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_cf_stmts.append(statement)
df_quarterly_cf_stmts= pd.DataFrame(quarterly_cf_stmts)
df_quarterly_cf_stmts
df_quarterly_cf_stmts = df_quarterly_cf_stmts.T
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts
df_quarterly_cf_stmts['endDate'] = quarterly_cf_data1
df_quarterly_cf_stmts['Ticker']='CI'
index = [str(i) for i in (df_quarterly_cf_stmts.index)]
df_quarterly_cf_stmts =pd.DataFrame(data=df_quarterly_cf_stmts ,index=index)
df_quarterly_cf_stmts['Field'] = index
df_quarterly_cf_stmts['Scrape Date'] = today
df_quarterly_cf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_cf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_cf=df_quarterly_cf_stmts
df_cf=df_cf[df_cf.Field.isin(tic)]
df_cf




quarterly_bf = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']
quarterly_bf_stmts=[]
for s in quarterly_bf:
    statement = {}
    quarterly_bf_data1 = json_data['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements'][0]['endDate']['fmt']
    for key, val in s.items():
        try:
            statement[key] = val['raw']
        except TypeError:
            continue
        except KeyError:
            continue
quarterly_bf_stmts.append(statement)
df_quarterly_bf_stmts= pd.DataFrame(quarterly_bf_stmts)
df_quarterly_bf_stmts
df_quarterly_bf_stmts = df_quarterly_bf_stmts.T
df_quarterly_bf_stmts
df_quarterly_bf_stmts['endDate'] = quarterly_bf_data1
df_quarterly_bf_stmts
df_quarterly_bf_stmts['Ticker']='CI'
index = [str(i) for i in (df_quarterly_bf_stmts.index)]
df_quarterly_bf_stmts =pd.DataFrame(data=df_quarterly_bf_stmts ,index=index)
df_quarterly_bf_stmts['Field'] = index
df_quarterly_bf_stmts['Scrape Date'] = today
df_quarterly_bf_stmts.rename(columns = {0:'Value'}, inplace = True)
df_quarterly_bf_stmts
tic = ['retainedEarnings','operatingIncome','netIncomeFromContinuingOps','retainedEarnings','changeInCash','netBorrowings']
df_bf=df_quarterly_bf_stmts
df_bf=df_bf[df_bf.Field.isin(tic)]
df_bf


df_union_all= pd.concat([df_is, df_cf, df_bf])
df_union_all
CI = df_union_all

# %%
Frames = pd.concat([JNJ,BRKB,JPM,MMM,ABBV,DIS,T,PG,LOW,CI])
df_new = Frames[['Ticker', 'Field', 'Value','endDate','Scrape Date']]
print(df_new)
df_new.to_csv('C:\Spark\spark-3.2.1-bin-hadoop2.7\Frames.csv', index=False)
# Out:
#                            Ticker                       Field         Value  \
# operatingIncome               JNJ             operatingIncome    6844000000
# netIncomeFromContinuingOps    JNJ  netIncomeFromContinuingOps    6197000000
# netBorrowings                 JNJ               netBorrowings   -1452000000
# changeInCash                  JNJ                changeInCash   -1314000000
# retainedEarnings              JNJ            retainedEarnings  116508000000
# operatingIncome             BRK-B             operatingIncome   15327000000
# netIncomeFromContinuingOps  BRK-B  netIncomeFromContinuingOps   11840000000
# netBorrowings               BRK-B               netBorrowings   -1637000000
# changeInCash                BRK-B                changeInCash   12092000000
# retainedEarnings            BRK-B            retainedEarnings  456337000000
# operatingIncome               JPM             operatingIncome   17725000000
# ...
